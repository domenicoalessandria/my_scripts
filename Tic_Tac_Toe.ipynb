# %% [markdown]
# ### Tic Tac Toe
#
# ###### 29\01\23 Update:
# - coding cleaning
# - added player class
# - the player who choose the marker also starts first but he\she is selected randomly
# - added name display of the moving player during marker's spot selection
#
# ##### features i'd like to add in the future
# - adding 'play-again?' feature
# - and then add the won games count of each player
#
# P.S. The feature about the random chosing first_mover made the code more complex.. maybe it is not wortj it.
# I know that the player class is, as of now, useless

# %%
import random
from IPython.display import clear_output

# %%
class Player:
    
    def __init__(self,name):
        
        self.name=''

# %%
def display_board(board):
    
    print(board[7],'|',board[8],'|',board[9])
    print('---------')
    print(board[4],'|',board[5],'|',board[6])
    print('---------')
    print(board[1],'|',board[2],'|',board[3])

# %%
def first_mover_f():
    
    global first_mover
    
    ran_num=random.randint(1,2)
    
    if ran_num==1:
        print(f'\n{one_name} choose first')
        first_mover=one_name
    else:
        print(f'\n{two_name} choose first')
        first_mover=two_name

# %%
def player_input():
    
    global marker_one
    global marker_two
    
    marker_one=''
    marker_two=''
    
    while marker_one!='X' and marker_one!='O':
        
        if first_mover==one_name:
            marker_one=input(f'\n{one_name}, please select X or O: ').upper()
        elif first_mover==two_name:
            marker_two=input(f'\n{two_name}, please select X or O: ').upper()
        
        if marker_one=='X':
            marker_two='O'
        elif marker_one=='O':
            marker_two='X'
        elif marker_two=='X':
            marker_one='O'
        elif marker_two=='O':
            marker_two='X'
            
        if marker_one not in ('X','O'):
            print("Sorry, need to enter either 'X' or 'O'!")
        
    print(f'{one_name} has {marker_one} as marker \n{two_name} has {marker_two} as marker')

# %%
def place_marker(board,turn_count):
    
    spot='wrong'
    
    while not spot.isdigit():
        
        print(f'first mover is{first_mover}')
        
        if first_mover==one_name:
            if turn_count%2!=0:
                moving_player=one_name
                print('A')
            elif turn_count%2!=0:
                moving_player=two_name
                print('B')
                
        if first_mover==two_name:
            if turn_count%2!=0:
                moving_player=two_name
                print('C')
            elif turn_count%2==0:
                moving_player=one_name
                print('D')
        spot=input(f'Please {moving_player} select a number between 1 and 9 in order to position your mark on the board: ')
            
        if not spot.isdigit():
            print('Please digit an actual number')
            
        elif int(spot) not in range(1,10):
            print('Selected number out of range')
            
        elif board[int(spot)]!=' ':
            print('Please select an empty position')
        
        else:
            if moving_player==one_name:
                board[int(spot)]=marker_one
            else:
                board[int(spot)]=marker_two

# %%
def win_check(board):
    
    for _ in range(1,8,3):
        if board[_]==marker_one and board[_+1]==marker_one and board[_+2]==marker_one:
            print(f'{one_name} won')
            return True
            break
        else: 
            pass
        
    for _ in range(1,4):
        if board[_]==marker_one and board[_+3]==marker_one and board[_+6]==marker_one:
            print(f'{one_name} won')
            return True
            break
        else: 
            pass 
        
    if board[1]==marker_one and board[5]==marker_one and board[9]==marker_one:
        print(f'{one_name} won')
        return True
    
    if board[3]==marker_one and board[5]==marker_one and board[7]==marker_one:
        print(f'{one_name} won')
        return True
        
        
    for _ in range(1,8,3):
        if board[_]==marker_two and board[_+1]==marker_two and board[_+2]==marker_two:
            print(f'{two_name} won')
            return True
            break
        else: 
            pass
        
    for _ in range(1,4):
        if board[_]==marker_two and board[_+3]==marker_two and board[_+6]==marker_two:
            print(f'{two_name} won')
            return True
            break
        else: 
            pass
        
    if board[1]==marker_two and board[5]==marker_two and board[9]==marker_two:
        print(f'{two_name} won')
        return True
        
    if board[3]==marker_two and board[5]==marker_two and board[7]==marker_two:
        print(f'{two_name} won')
        return True
    
    return False

# %%
def board_full(board):
    if board==['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']:
        return False
    elif ' ' in board[1:10]:
        return False
    else:
        return True

# %%
##Initializing the board variable 
board=['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']

##Collecting the players' names
one_name=input('Player 1, digit your name: ')
two_name=input('Player 2, digit your name: ')

one=Player(one_name)
two=Player(two_name)

##Randomly selecting the first mover
first_mover_f()

##Markers selection
player_input()


##Setting end-game conditions
board_full(board)
win_check(board)

print('\nConsider a numpad mirroring the game table, then select the position of your marker \nby choosing a number between 1 and 9 accordingly')

print('like this:\n')

print('7','|','8','|','9')
print('---------')
print('4','|','5','|','6')
print('---------')
print('1','|','2','|','3')

print('\n\n')

##initializing the turn_count variable
turn_count=1
    
##Starting the actual game
while not win_check(board) and not board_full(board):
    display_board(board)
    place_marker(board,turn_count)
    turn_count+=1
    print(f'turn count is {turn_count}')
    print(first_mover)
# Out:
# Player 1, digit your name: dom
# Player 2, digit your name: lud
#
# lud choose first
#
# lud, please select X or O: x
# dom has O as marker
# lud has X as marker
#
# Consider a numpad mirroring the game table, then select the position of your marker
# by choosing a number between 1 and 9 accordingly
# like this:
#
# 7 | 8 | 9
# ---------
# 4 | 5 | 6
# ---------
# 1 | 2 | 3
#
#
#
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# first mover islud
# C
# Please lud select a number between 1 and 9 in order to position your mark on the board: 1
# turn count is 2
# lud
#   |   |
# ---------
#   |   |
# ---------
# X |   |
# first mover islud
# D
# Please dom select a number between 1 and 9 in order to position your mark on the board: 2
# turn count is 3
# lud
#   |   |
# ---------
#   |   |
# ---------
# X | O |
# first mover islud
# C
# Please lud select a number between 1 and 9 in order to position your mark on the board: 3
# turn count is 4
# lud
#   |   |
# ---------
#   |   |
# ---------
# X | O | X
# first mover islud
# D
# Please dom select a number between 1 and 9 in order to position your mark on the board: 4
# turn count is 5
# lud
#   |   |
# ---------
# O |   |
# ---------
# X | O | X
# first mover islud
# C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42564\46878419.py in <module>
#      38 while not win_check(board) and not board_full(board):
#      39     display_board(board)
# ---> 40     place_marker(board,turn_count)
#      41     turn_count+=1
#      42     print(f'turn count is {turn_count}')
#
# ~\AppData\Local\Temp\ipykernel_42564\3465673541.py in place_marker(board, turn_count)
#      22                 moving_player=one_name
#      23                 print('D')
# ---> 24         spot=input(f'Please {moving_player} select a number between 1 and 9 in order to position your mark on the board: ')
#      25
#      26         if not spot.isdigit():
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
